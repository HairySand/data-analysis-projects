# %% [markdown]
# # Data Manipulation Studio
#
# For this studio, we will revisit the data set from our last studio. If you recall, California farmers were looking for advice on growing pumpkins. We will use the same pumpkins dataset as provided by the U.S. Department of Agriculture. You may have to clean data in the process of data manipulation, so feel free to pull up your notebook from the last class's studio.
#
# We will now be focusing our attention on a different region in the United States, the Northeast. When you open up the dataset folder, you will have 13 CSVs, including the San Francisco and Los Angeles data from the last lesson. The 13 CSVs are each a different terminal market in the United States.
#
# A terminal market is a central site, often in a metropolitan area, that serves as an assembly and trading place for commodities. Terminal markets for agricultural commodities are usually at or near major transportation hubs. Definition Source
#
# ## Getting Started
#
# Import the CSVs for each of the following cities: Baltimore, Boston, New York, and Philadelphia. Set up a dataframe for each city.

# %%
# Import the necessary libraries and CSVs. Make some dataframes!
import pandas as pd
import numpy as np
baltimore = pd.read_csv(r"C:\Users\LC Harrison Sand\OneDrive\Documents\LaunchCode\data-analysis-projects\data-manipulation\studio\data-manipulation-studio\dataset\baltimore_9-24-2016_9-30-2017.csv")
boston = pd.read_csv(r"C:\Users\LC Harrison Sand\OneDrive\Documents\LaunchCode\data-analysis-projects\data-manipulation\studio\data-manipulation-studio\dataset\boston_9-24-2016_9-30-2017.csv")
new_york = pd.read_csv(r"C:\Users\LC Harrison Sand\OneDrive\Documents\LaunchCode\data-analysis-projects\data-manipulation\studio\data-manipulation-studio\dataset\new-york_9-24-2016_9-30-2017.csv")
philly = pd.read_csv(r"C:\Users\LC Harrison Sand\OneDrive\Documents\LaunchCode\data-analysis-projects\data-manipulation\studio\data-manipulation-studio\dataset\philadelphia_9-24-2016_9-30-2017.csv")

# %% [markdown]
# ## Clean Your Data
#
#     "In the last lesson, we cleaned the data related to San Francisco. Pull up your notebook from the last lesson and use it as a reference to clean up these new dataframes."

# %%
print("Baltimore")
for col in baltimore.columns:
    pct_missing = np.mean(baltimore[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
    
print("----------------------------------------------------------------------------------------")
print("Boston")
for col in boston.columns:
    pct_missing = np.mean(boston[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))

print("----------------------------------------------------------------------------------------")
print("New York")
for col in new_york.columns:
    pct_missing = np.mean(new_york[col].isnull())
   
    print('{} - {}%'.format(col, round(pct_missing*100)))
print("----------------------------------------------------------------------------------------")
print("Philly")
for col in philly.columns:
    pct_missing = np.mean(philly[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))



for data in [baltimore, boston, new_york, philly]:
    data["Type"] = data["Type"].fillna("Conventional")
    data["Variety"] = data["Variety"].fillna("Other")
    data = data.drop(["Trans Mode", "Grade", "Environment" "Crop", "Storage", "Condition", "Quality", "Unit of Sale", "Origin District", "Environment"], axis=1)
# Out:
# Baltimore
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 1%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 3%
# Origin District - 100%
# Item Size - 16%
# Color - 80%
# Environment - 100%
# Unit of Sale - 84%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# ----------------------------------------------------------------------------------------
# Boston
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 92%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 81%
# Item Size - 1%
# Color - 14%
# Environment - 100%
# Unit of Sale - 87%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# ----------------------------------------------------------------------------------------
# New York
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 84%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 87%
# Item Size - 7%
# Color - 81%
# Environment - 100%
# Unit of Sale - 78%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# ----------------------------------------------------------------------------------------
# Philly
# Commodity Name - 0%
# City Name - 0%
# Type - 100%
# Package - 0%
# Variety - 0%
# Sub Variety - 79%
# Grade - 100%
# Date - 0%
# Low Price - 0%
# High Price - 0%
# Mostly Low - 0%
# Mostly High - 0%
# Origin - 0%
# Origin District - 100%
# Item Size - 21%
# Color - 100%
# Environment - 100%
# Unit of Sale - 81%
# Quality - 100%
# Condition - 100%
# Appearance - 100%
# Storage - 100%
# Crop - 100%
# Repack - 0%
# Trans Mode - 100%
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 29
#      27 data["Type"] = data["Type"].fillna("Conventional")
#      28 data["Variety"] = data["Variety"].fillna("Other")
# ---> 29 data = data.drop(["Trans Mode", "Grade", "Environment" "Crop", "Storage", "Condition", "Quality", "Unit of Sale", "Origin District", "Environment"], axis=1)
#
# File ~\onedrive\documents\launchcode\data-analysis-projects\venv\Lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
#    5589     )
#
# File ~\onedrive\documents\launchcode\data-analysis-projects\venv\Lib\site-packages\pandas\core\generic.py:4788, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786 for axis, labels in axes.items():
#    4787     if labels is not None:
# -> 4788         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4790 if inplace:
#    4791     self._update_inplace(obj)
#
# File ~\onedrive\documents\launchcode\data-analysis-projects\venv\Lib\site-packages\pandas\core\generic.py:4830, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4828         new_axis = axis.drop(labels, level=level, errors=errors)
#    4829     else:
# -> 4830         new_axis = axis.drop(labels, errors=errors)
#    4831     indexer = axis.get_indexer(new_axis)
#    4833 # Case for non-unique axis
#    4834 else:
#
# File ~\onedrive\documents\launchcode\data-analysis-projects\venv\Lib\site-packages\pandas\core\indexes\base.py:7070, in Index.drop(self, labels, errors)
#    7068 if mask.any():
#    7069     if errors != "ignore":
# -> 7070         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7071     indexer = indexer[~mask]
#    7072 return self.delete(indexer)
#
# KeyError: "['EnvironmentCrop'] not found in axis"

# %% [markdown]
# ## Combine Your Data
#
# Now that you have four clean sets of data, combine all four into one dataframe that represents the entire Northeast region.

# %%
# Combine the four dataframes into one!
northeast = pd.concat([baltimore, boston, new_york, philly], ignore_index= True)
northeast
# Out:
#     Commodity Name     City Name          Type             Package  \
# 0         PUMPKINS     BALTIMORE  Conventional        24 inch bins
# 1         PUMPKINS     BALTIMORE  Conventional        24 inch bins
# 2         PUMPKINS     BALTIMORE  Conventional        24 inch bins
# 3         PUMPKINS     BALTIMORE  Conventional        24 inch bins
# 4         PUMPKINS     BALTIMORE  Conventional        24 inch bins
# ..             ...           ...           ...                 ...
# 669       PUMPKINS  PHILADELPHIA           NaN  1/2 bushel cartons
# 670       PUMPKINS  PHILADELPHIA           NaN  1/2 bushel cartons
# 671       PUMPKINS  PHILADELPHIA           NaN  1/2 bushel cartons
# 672       PUMPKINS  PHILADELPHIA           NaN  1/2 bushel cartons
# 673       PUMPKINS  PHILADELPHIA           NaN  1/2 bushel cartons
#
#          Variety Sub Variety  Grade        Date  Low Price  High Price  ...  \
# 0          Other         NaN    NaN  04/29/2017        270       280.0  ...
# 1          Other         NaN    NaN  05/06/2017        270       280.0  ...
# 2    HOWDEN TYPE         NaN    NaN  09/24/2016        160       160.0  ...
# 3    HOWDEN TYPE         NaN    NaN  09/24/2016        160       160.0  ...
# 4    HOWDEN TYPE         NaN    NaN  11/05/2016         90       100.0  ...
# ..           ...         ...    ...         ...        ...         ...  ...
# 669    MINIATURE   FLAT TYPE    NaN  11/05/2016         16        18.0  ...
# 670    MINIATURE   FLAT TYPE    NaN  08/26/2017         18        20.0  ...
# 671    MINIATURE   FLAT TYPE    NaN  09/16/2017         16        16.0  ...
# 672    MINIATURE   FLAT TYPE    NaN  09/23/2017         15        16.0  ...
# 673    MINIATURE   FLAT TYPE    NaN  09/30/2017         15        18.0  ...
#
#      Color  Environment Unit of Sale Quality Condition Appearance  Storage  \
# 0      NaN          NaN          NaN     NaN       NaN        NaN      NaN
# 1      NaN          NaN          NaN     NaN       NaN        NaN      NaN
# 2      NaN          NaN          NaN     NaN       NaN        NaN      NaN
# 3      NaN          NaN          NaN     NaN       NaN        NaN      NaN
# 4      NaN          NaN          NaN     NaN       NaN        NaN      NaN
# ..     ...          ...          ...     ...       ...        ...      ...
# 669    NaN          NaN   SHELLACKED     NaN       NaN        NaN      NaN
# 670    NaN          NaN   SHELLACKED     NaN       NaN        NaN      NaN
# 671    NaN          NaN   SHELLACKED     NaN       NaN        NaN      NaN
# 672    NaN          NaN   SHELLACKED     NaN       NaN        NaN      NaN
# 673    NaN          NaN   SHELLACKED     NaN       NaN        NaN      NaN
#
#     Crop  Repack  Trans Mode
# 0    NaN       E         NaN
# 1    NaN       E         NaN
# 2    NaN       N         NaN
# 3    NaN       N         NaN
# 4    NaN       N         NaN
# ..   ...     ...         ...
# 669  NaN       N         NaN
# 670  NaN       N         NaN
# 671  NaN       N         NaN
# 672  NaN       N         NaN
# 673  NaN       N         NaN
#
# [674 rows x 25 columns]

# %% [markdown]
# ## Answer Some Questions
#
# Use `groupby()` and `agg()` to answer the following two questions:
#
# 1    "1. What is the mean low and high prices for each type of **unit of sale** in the Northeast region?",
#     "2. For each region, what is the average number of pumpkins per variety that came into terminal markets for the year? "

# %%
# Put your code here to find the mean low and high prices in the Northeast region for each type of unit of sale.
prices = ["Low Price", "High Price"]
mean_prices = northeast[prices].agg("mean")
print("NorthEast Prices:")
mean_prices
# Out:
# NorthEast Prices:
# Low Price     134.183976
# High Price    150.671365
# dtype: float64

# %%
# Put your code here to find the average number of pumpkins coming into terminal markets of each variety.
varieties = northeast.groupby("Variety").nunique()
varieties
# Out:
#                           Commodity Name  City Name  Type  Package  \
# Variety
# BIG MACK TYPE                          1          3     1        3
# BLUE TYPE                              1          1     0        1
# CINDERELLA                             1          2     1        2
# FAIRYTALE                              1          2     1        2
# HOWDEN TYPE                            1          4     1        2
# HOWDEN WHITE TYPE                      1          1     1        1
# KNUCKLE HEAD                           1          3     0        2
# MINIATURE                              1          4     1        3
# MIXED HEIRLOOM VARIETIES               1          2     1        1
# Other                                  1          1     1        1
# PIE TYPE                               1          4     1        5
#
#                           Sub Variety  Grade  Date  Low Price  High Price  \
# Variety
# BIG MACK TYPE                       0      0    11          6           7
# BLUE TYPE                           0      0     7          1           1
# CINDERELLA                          0      0    18         11          10
# FAIRYTALE                           0      0    10          8           8
# HOWDEN TYPE                         0      0    11         12          14
# HOWDEN WHITE TYPE                   0      0     2          2           1
# KNUCKLE HEAD                        0      0     7          3           3
# MINIATURE                           2      0    12          7           7
# MIXED HEIRLOOM VARIETIES            0      0     4          3           2
# Other                               0      0     2          1           1
# PIE TYPE                            0      0    18         24          27
#
#                           Mostly Low  ...  Color  Environment  Unit of Sale  \
# Variety                               ...
# BIG MACK TYPE                      9  ...      2            0             2
# BLUE TYPE                          1  ...      1            0             0
# CINDERELLA                        11  ...      2            0             0
# FAIRYTALE                          8  ...      2            0             0
# HOWDEN TYPE                       20  ...      1            0             1
# HOWDEN WHITE TYPE                  2  ...      0            0             0
# KNUCKLE HEAD                       3  ...      1            0             0
# MINIATURE                          7  ...      2            0             1
# MIXED HEIRLOOM VARIETIES           3  ...      0            0             0
# Other                              1  ...      0            0             0
# PIE TYPE                          26  ...      2            0             1
#
#                           Quality  Condition  Appearance  Storage  Crop  \
# Variety
# BIG MACK TYPE                   0          0           0        0     0
# BLUE TYPE                       0          0           0        0     0
# CINDERELLA                      0          0           0        0     0
# FAIRYTALE                       0          0           0        0     0
# HOWDEN TYPE                     0          0           0        0     0
# HOWDEN WHITE TYPE               0          0           0        0     0
# KNUCKLE HEAD                    0          0           0        0     0
# MINIATURE                       0          0           0        0     0
# MIXED HEIRLOOM VARIETIES        0          0           0        0     0
# Other                           0          0           0        0     0
# PIE TYPE                        0          0           0        0     0
#
#                           Repack  Trans Mode
# Variety
# BIG MACK TYPE                  1           0
# BLUE TYPE                      1           0
# CINDERELLA                     2           0
# FAIRYTALE                      1           0
# HOWDEN TYPE                    1           0
# HOWDEN WHITE TYPE              1           0
# KNUCKLE HEAD                   1           0
# MINIATURE                      1           0
# MIXED HEIRLOOM VARIETIES       1           0
# Other                          1           0
# PIE TYPE                       1           0
#
# [11 rows x 24 columns]

# %% [markdown]
# ## Bonus Mission
#
# Try answering the same questions for the Midwest (Chicago, Detroit, and St. Louis) or the Southeast (Atlanta, Columbia, and Miami) regions.

# %%
# Try the bonus mission if you have time!
