# %%
import pandas as pd
import matplotlib as plot
import numpy as np

# %%
dys_db = pd.read_csv(r"C:\Users\LC Harrison Sand\Documents\DBs\ScienceFictionDB\sf_dystopia.csv", index_col = "Book_Title")

display(dys_db.head(5))
display(dys_db.tail(5))
# Out:
#                    Original_Book_Title      Author_Name Edition_Language  \
# Book_Title
# The Hunger Games      The Hunger Games  Suzanne Collins          English
# Catching Fire            Catching Fire  Suzanne Collins          English
# Mockingjay                  Mockingjay  Suzanne Collins          English
# Divergent                    Divergent    Veronica Roth          English
# 1984              Nineteen Eighty-Four    George Orwell          English
#
#                   Rating_score  Rating_votes  Review_number  \
# Book_Title
# The Hunger Games          4.33       6570886         174054
# Catching Fire             4.29       2605247          97929
# Mockingjay                4.05       2419502         102438
# Divergent                 4.19       3007473         109091
# 1984                      4.19       3275862          73090
#
#                                                    Book_Description  \
# Book_Title
# ...

# %%
display(dys_db.info())
display(dys_db.isnull().sum())
display(dys_db.index)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1242 entries, The Hunger Games to Smoke
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Original_Book_Title  1242 non-null   object
#  1   Author_Name          1242 non-null   object
#  2   Edition_Language     1210 non-null   object
#  3   Rating_score         1242 non-null   float64
#  4   Rating_votes         1242 non-null   int64
#  5   Review_number        1242 non-null   int64
#  6   Book_Description     1241 non-null   object
#  7   Year_published       1242 non-null   int64
#  8   Genres               1242 non-null   object
#  9   url                  1242 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 106.7+ KB
# None
# Original_Book_Title     0
# Author_Name             0
# Edition_Language       32
# Rating_score            0
# Rating_votes            0
# Review_number           0
# ...

# %%
display(dys_db.describe())
# Out:
#        Rating_score  Rating_votes  Review_number  Year_published
# count   1242.000000  1.242000e+03    1242.000000     1242.000000
# mean       3.911844  8.590806e+04    4964.190821     2002.611916
# std        0.278156  3.163641e+05   11313.237182       84.109072
# min        2.810000  6.700000e+02      38.000000        0.000000
# 25%        3.720000  5.140500e+03     596.000000     2008.250000
# 50%        3.920000  1.340100e+04    1363.500000     2012.000000
# 75%        4.110000  4.710625e+04    4237.750000     2014.000000
# max        4.570000  6.570886e+06  174054.000000     2020.000000

# %%
dys_db.loc[dys_db["Year_published"] == 0]
# Out:
# Empty DataFrame
# Columns: [Original_Book_Title, Author_Name, Edition_Language, Rating_score, Rating_votes, Review_number, Book_Description, Year_published, Genres, url, Year_Published]
# Index: []

# %%
dys_db.loc[((dys_db.index == "The Seeker") & (dys_db["Author_Name"] == "Stephenie Meyer")), "Year_published"] = 2015

# %%
dys_db.index = dys_db.index.str.strip()
dys_db["Author_Name"] = dys_db["Author_Name"].str.strip()
dys_db.loc[((dys_db.index == "Juniper Unraveling") & (dys_db["Author_Name"] == "Keri Lake")), "Year_published"] = 2017

# %%
print(dys_db.loc[((dys_db.index == "Juniper Unraveling") & (dys_db["Author_Name"] == "Keri Lake"))])
# Out:
#                          Original_Book_Title Author_Name Edition_Language  \
# Book_Title
# Juniper Unraveling  \nJuniper Unraveling #1    Keri Lake              NaN
#
#                     Rating_score  Rating_votes  Review_number  \
# Book_Title
# Juniper Unraveling          4.14          1313            296
#
#                                                      Book_Description  \
# Book_Title
# Juniper Unraveling  Papa says everyone has a story that deserves t...
#
#                     Year_published  \
# Book_Title
# Juniper Unraveling            2017
#
#                                                                Genres  \
# Book_Title
# Juniper Unraveling  {'Dark': 66, 'Romance': 60, 'Science Fiction (...
#
#                                                                   url  \
# Book_Title
# Juniper Unraveling  https://www.goodreads.com/book/show/35172048-j...
#
#                     Year_Published
# Book_Title
# Juniper Unraveling          2017.0
